# %% [markdown]
# ## Demonstration of ogcapi API

# %% [markdown]
# The initial attempt to use the `owslib` library failed due to issus in the requests getting through to the F5.

# %% [raw]
# from owslib.ogcapi.features import Features
# bgs = Features('https://ogcapi.bgs.ac.uk')
# bgs.collection_items('recentearthquakes', limit=10)

# %% [markdown]
# Work from here down uses `requests` directly.

# %%
import folium
import requests

# %% [markdown]
# ### Get some GeoJSON data and display it directly on a `folium` map.

# %%
# Get the data
params = {'f': 'json', 'limit': 10}
response = requests.get('https://ogcapi.bgs.ac.uk/collections/recentearthquakes/items', params=params)
data = response.json()

# %%
# Define an initial map centred on and zoomed to the UK
m = folium.Map(location=[55, -2], zoom_start=5)

# %%
# Use a style function to set the style dynamically per data point
# In this case use the magnitude to set the radius of the marker
def style_function(feature):
    radius = feature['properties']['ml'] * 5
    return {'radius': radius,
            'color': 'red',
            'weight': 2}

# %%
# Create a basic unstyled tooltip
tooltip = folium.features.GeoJsonTooltip(
    fields=['ml'],
    aliases=['magnitude'])

# %%
# Create a basic unstyled popup
popup = folium.features.GeoJsonPopup(
    fields=["year", "latitude", "longitude", "depth", "ml", "intensity"],
    aliases=["year", "latitude", "longitude", "depth", "magnitude", "intensity"])

# %%
# Populate and display the map
folium.GeoJson(
    data,
    tooltip=tooltip,
    popup=popup,
    style_function=style_function,
    marker=folium.CircleMarker()
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3e7261c8ec655841673f666e62bf5d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3e7261c8ec655841673f666e62bf5d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c3e7261c8ec655841673f666e62bf5d5 = L.map(
#                 &quot;map_c3e7261c8ec655841673f666e62bf5d5&quot;,
#                 {
#                     center: [55.0, -2.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4ca725a0b6f9b50deb4c32b6652aea8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c3e7261c8ec655841673f666e62bf5d5);
#
#
#         function geo_json_3236f024bc5ebad2beeb90f411db2622_styler(feature) {
#             switch(feature.id) {
#                 case 86123.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5.0, &quot;weight&quot;: 2};
#                 case 92221.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 15.0, &quot;weight&quot;: 2};
#                 case 92223.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 16.0, &quot;weight&quot;: 2};
#                 case 92224.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 15.5, &quot;weight&quot;: 2};
#                 case 92225.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 6.0, &quot;weight&quot;: 2};
#                 case 92226.0: case 92229.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 6.5, &quot;weight&quot;: 2};
#                 case 92228.0:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 9.0, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3236f024bc5ebad2beeb90f411db2622_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3236f024bc5ebad2beeb90f411db2622_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3236f024bc5ebad2beeb90f411db2622_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3236f024bc5ebad2beeb90f411db2622 = L.geoJson(null, {
#                 onEachFeature: geo_json_3236f024bc5ebad2beeb90f411db2622_onEachFeature,
#
#                 style: geo_json_3236f024bc5ebad2beeb90f411db2622_styler,
#                 pointToLayer: geo_json_3236f024bc5ebad2beeb90f411db2622_pointToLayer
#         });
#
#         function geo_json_3236f024bc5ebad2beeb90f411db2622_add (data) {
#             geo_json_3236f024bc5ebad2beeb90f411db2622
#                 .addData(data)
#                 .addTo(map_c3e7261c8ec655841673f666e62bf5d5);
#         }
#             geo_json_3236f024bc5ebad2beeb90f411db2622_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-3.699999999999998, 53.86000000000002], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 86123.0, &quot;properties&quot;: {&quot;date_entered&quot;: &quot;2018-08-29T17:28:59&quot;, &quot;date_updated&quot;:

# %% [markdown]
# ### Now get the data into geopandas, transform it and then create a map

# %%
import geopandas as gpd
import pandas as pd
import branca.colormap as cm
from shapely.geometry import Polygon

# %%
# Get all the data in batches of 'limit'.
# This is a bit ugly, there may be a neater way.
earthquake_list = []
offset = 0
limit = 500
params = {'f': 'json', 'offset': offset, 'limit': limit}
response = requests.get('https://ogcapi.bgs.ac.uk/collections/recentearthquakes/items', params=params)
data = response.json()
while len(data['features']) == limit:
    # Get JSON into GeoPandas
    earthquake_list.append(gpd.GeoDataFrame.from_features(data['features']))
    # Get the next batch
    offset += limit
    params = {'f': 'json', 'offset': offset, 'limit': limit}
    response = requests.get('https://ogcapi.bgs.ac.uk/collections/recentearthquakes/items', params=params)
    data = response.json()

# Add the final batch if not empty
if len(data['features']) > 0:
    earthquake_list.append(gpd.GeoDataFrame.from_features(data['features']))

# Concatenate dataframes into one
earthquakes = pd.concat(
    earthquake_list,
    ignore_index=True,
)
# Set geometry
earthquakes = earthquakes.set_geometry('geometry')
earthquakes.tail()
# Out:
#                        geometry  year  longitude   ml  intensity  \
# 9923  POINT (-3.85200 53.13100)  2022     -3.852  1.8        0.0
# 9924  POINT (-3.85200 53.13100)  2022     -3.852  1.8        0.0
# 9925  POINT (-3.85200 53.13100)  2022     -3.852  1.8        0.0
# 9926  POINT (-3.85200 53.13100)  2022     -3.852  1.8        0.0
# 9927  POINT (-3.46100 56.15600)  2022     -3.461  1.0        0.0
#
#              date_entered date_updated  latitude             datetime  depth  \
# 9923  2022-10-13T06:00:01         None    53.131  2022-10-11T08:37:12    7.8
# 9924  2022-10-15T06:00:02         None    53.131  2022-10-11T08:37:12    7.8
# 9925  2022-10-17T06:00:00         None    53.131  2022-10-11T08:37:12    7.8
# 9926  2022-10-19T06:00:00         None    53.131  2022-10-11T08:37:12    7.8
# 9927  2022-10-21T06:00:00         None    56.156  2022-10-19T19:33:30    3.8
#
#      user_entered user_updated
# 9923       SYSTEM         None
# 9924       SYSTEM         None
# 9925       SYSTEM         None
# 9926       SYSTEM         None
# 9927       SYSTEM         None

# %%
earthquakes.dtypes
# Out:
# geometry        geometry
# year              object
# longitude        float64
# ml               float64
# intensity        float64
# date_entered      object
# date_updated      object
# latitude         float64
# datetime          object
# depth            float64
# user_entered      object
# user_updated      object
# dtype: object

# %%
# Rename, convert and select columns. Set the CRS.
earthquakes.rename(columns={'id': 'id', 'ml': 'magnitude'}, inplace=True)
# earthquakes['datetime'] = pd.to_datetime(earthquakes['datetime']) # leave as string for now
earthquakes['id'] = earthquakes['id'].astype(int)
earthquakes = earthquakes[['id', 'datetime', 'magnitude', 'intensity', 'depth', 'geometry']]
earthquakes.set_crs(epsg=4326, inplace=True)
earthquakes.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\edlew\Anaconda3\envs\ogcapi\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\edlew\Anaconda3\envs\ogcapi\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\edlew\Anaconda3\envs\ogcapi\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\edlew\Documents\GIT\BGS-OGCAPI-Documentation\notebooks\ogcapi-features-cql-requests-earthquakes.ipynb Cell 17 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/edlew/Documents/GIT/BGS-OGCAPI-Documentation/notebooks/ogcapi-features-cql-requests-earthquakes.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> earthquakes.rename(columns={'id': 'id', 'ml': 'magnitude'}, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/edlew/Documents/GIT/BGS-OGCAPI-Documentation/notebooks/ogcapi-features-cql-requests-earthquakes.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a> # earthquakes['datetime'] = pd.to_datetime(earthquakes['datetime']) # leave as string for now
# ----> <a href='vscode-notebook-cell:/c%3A/Users/edlew/Documents/GIT/BGS-OGCAPI-Documentation/notebooks/ogcapi-features-cql-requests-earthquakes.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> earthquakes['id'] = earthquakes['id'].astype(int)
#       <a href='vscode-notebook-cell:/c%3A/Users/edlew/Documents/GIT/BGS-OGCAPI-Documentation/notebooks/ogcapi-features-cql-requests-earthquakes.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> earthquakes = earthquakes[['id', 'datetime', 'magnitude', 'intensity', 'depth', 'geometry']]
#       <a href='vscode-notebook-cell:/c%3A/Users/edlew/Documents/GIT/BGS-OGCAPI-Documentation/notebooks/ogcapi-features-cql-requests-earthquakes.ipynb#X62sZmlsZQ%3D%3D?line=5'>6</a> earthquakes.set_crs(epsg=4326, inplace=True)
#
# File c:\Users\edlew\Anaconda3\envs\ogcapi\lib\site-packages\geopandas\geodataframe.py:1415, in GeoDataFrame.__getitem__(self, key)
#    1409 def __getitem__(self, key):
#    1410     """
#    1411     If the result is a column containing only 'geometry', return a
#    1412     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1413     return a GeoDataFrame.
#    1414     """
# -> 1415     result = super().__getitem__(key)
#    1416     geo_col = self._geometry_column_name
#    1417     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File c:\Users\edlew\Anaconda3\envs\ogcapi\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File c:\Users\edlew\Anaconda3\envs\ogcapi\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'id'

# %%
earthquakes.dtypes
# Out:
# geometry        geometry
# year              object
# longitude        float64
# magnitude        float64
# intensity        float64
# date_entered      object
# date_updated      object
# latitude         float64
# datetime          object
# depth            float64
# user_entered      object
# user_updated      object
# dtype: object

# %%
earthquakes.describe()
# Out:
#          longitude    magnitude    intensity     latitude        depth
# count  9928.000000  9928.000000  9928.000000  9928.000000  9411.000000
# mean     -2.384039     1.697774     0.247683    55.181075     7.441877
# std       2.823507     0.639514     0.880600     3.010857     8.121938
# min     -11.890000     1.000000     0.000000    49.001000     0.000000
# 25%      -4.368000     1.200000     0.000000    53.060000     1.900000
# 50%      -3.040000     1.500000     0.000000    55.098000     5.500000
# 75%      -1.200000     2.000000     0.000000    56.481250    10.400000
# max       5.000000     5.400000     6.000000    63.000000   183.700000

# %%
# Get the earthquakes above magnitude 4
big_quakes = earthquakes[earthquakes['magnitude'] >= 4]
big_quakes
# Out:
#                        geometry  year  longitude  magnitude  intensity  \
# 44    POINT (-2.47000 54.50000)  1970     -2.470        4.1        5.0
# 52     POINT (2.80000 59.40000)  1971      2.800        4.7        0.0
# 113   POINT (-3.12000 51.64000)  1974     -3.120        4.1        0.0
# 240    POINT (2.00000 62.00000)  1976      2.000        4.2        0.0
# 289    POINT (3.00000 61.50000)  1977      3.000        4.4        0.0
# ...                         ...   ...        ...        ...        ...
# 9582   POINT (4.12900 61.80400)  2022      4.129        4.2        0.0
# 9646  POINT (-1.61100 52.28200)  2000     -1.611        4.2        5.0
# 9655   POINT (1.92700 59.94300)  2000      1.927        4.5        0.0
# 9688   POINT (3.25900 56.68200)  2001      3.259        4.2        0.0
# 9764   POINT (2.27800 61.56600)  2022      2.278        5.2        4.0
#
#              date_entered date_updated  latitude             datetime  depth  \
# 44    2018-08-29T17:29:10         None    54.500  1970-08-09T20:09:01   20.9
# 52    2018-08-29T17:29:10         None    59.400  1971-03-23T20:05:18    NaN
# 113   2018-08-29T17:29:11         None    51.640  1974-02-25T20:03:43    NaN
# 240   2018-08-29T17:29:11         None    62.000  1976-08-18T20:45:52    NaN
# 289   2018-08-29T17:29:11         None    61.500  1977-04-06T19:32:04    NaN
# ...                   ...          ...       ...                  ...    ...
# 9582  2022-08-28T06:00:02         None    61.804  2022-08-26T01:47:11   19.1
# 9646  2022-08-30T06:00:00         None    52.282  2000-09-23T04:23:45   15.2
# 9655  2022-08-30T06:00:00         None    59.943  2000-12-08T05:54:01    9.8
# 9688  2022-08-30T06:00:00         None    56.682  2001-05-07T09:43:33    1.0
# 9764  2022-09-11T06:00:02         None    61.566  2022-03-21T05:32:55   10.0
#
#      user_entered user_updated
# 44           APBE         None
# 52           APBE         None
# 113          APBE         None
# 240          APBE         None
# 289          APBE         None
# ...           ...          ...
# 9582       SYSTEM         None
# 9646       SYSTEM         None
# 9655       SYSTEM         None
# 9688       SYSTEM         None
# 9764       SYSTEM         None
#
# [93 rows x 12 columns]

# %%
# Use shapely to get the centre of the map
bounds = Polygon(list(big_quakes['geometry'])).bounds
bounds
# Out:
# (-10.904000000000044, 49.15299999999999, 5.000000000000001, 62.67000000000002)

# %%
mag_min = big_quakes['magnitude'].min()
mag_max = big_quakes['magnitude'].max()

# %%
# Create a colormap using the min and max magnitudes
colormap = cm.LinearColormap(colors=['yellow','red'], caption='Magnitude', vmin=mag_min, vmax=mag_max)

# Define a style function to apply that map
def map_style_function(feature):
    color = colormap(feature['properties']['magnitude'])
    return {'radius': 3,
            'color': color,
            'fill': True,
            'fill_opacity': 1}

# Define an initial map centred on the points
m2 = folium.Map(
    location=[(bounds[1] + bounds[3])/2, (bounds[0] + bounds[2])/2],
    zoom_start=4)

# Create popup
popup = folium.features.GeoJsonPopup(fields=["datetime", "magnitude", "intensity", "depth"])

# Populate the map, converting the dataframe to JSON
folium.GeoJson(
    big_quakes.to_json(),
    popup=popup,
    style_function=map_style_function,
    marker=folium.CircleMarker()
).add_to(m2)

# Add colormap to map and display the map
m2.add_child(colormap)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2d43557ba79b3cbe0c379fed98bf417 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2d43557ba79b3cbe0c379fed98bf417&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a2d43557ba79b3cbe0c379fed98bf417 = L.map(
#                 &quot;map_a2d43557ba79b3cbe0c379fed98bf417&quot;,
#                 {
#                     center: [55.911500000000004, -2.9520000000000217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3587144584dfaccea657883370b94ea2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a2d43557ba79b3cbe0c379fed98bf417);
#
#
#         function geo_json_ecc5e93b2bf864e141a518477d940531_styler(feature) {
#             switch(feature.id) {
#                 case &quot;44&quot;: case &quot;113&quot;: case &quot;1527&quot;: case &quot;3032&quot;: case &quot;3845&quot;: case &quot;4084&quot;: case &quot;5555&quot;: case &quot;6035&quot;: case &quot;6942&quot;: case &quot;6944&quot;: case &quot;7098&quot;: case &quot;7100&quot;: case &quot;8917&quot;:
#                     return {&quot;color&quot;: &quot;#ffed00ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;52&quot;: case &quot;416&quot;: case &quot;3042&quot;: case &quot;5901&quot;: case &quot;5908&quot;: case &quot;5972&quot;: case &quot;6006&quot;: case &quot;6050&quot;: case &quot;8014&quot;:
#                     return {&quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;240&quot;: case &quot;1418&quot;: case &quot;2751&quot;: case &quot;4000&quot;: case &quot;4052&quot;: case &quot;6005&quot;: case &quot;6292&quot;: case &quot;6365&quot;: case &quot;8974&quot;: case &quot;9578&quot;: case &quot;9582&quot;: case &quot;9646&quot;: case &quot;9688&quot;:
#                     return {&quot;color&quot;: &quot;#ffdb00ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;289&quot;: case &quot;295&quot;: case &quot;348&quot;: case &quot;2621&quot;: case &quot;6026&quot;: case &quot;6402&quot;:
#                     return {&quot;color&quot;: &quot;#ffb600ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;324&quot;: case &quot;941&quot;:
#                     return {&quot;color&quot;: &quot;#ff6d00ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;1107&quot;: case &quot;6877&quot;: case &quot;7224&quot;:
#                     return {&quot;color&quot;: &quot;#ff0000ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;1136&quot;: case &quot;3197&quot;: case &quot;5707&quot;: case &quot;6235&quot;: case &quot;7698&quot;:
#                     return {&quot;color&quot;: &quot;#ffc900ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;2409&quot;:
#                     return {&quot;color&quot;: &quot;#ff3600ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;4001&quot;: case &quot;6301&quot;: case &quot;7021&quot;: case &quot;7177&quot;: case &quot;8846&quot;:
#                     return {&quot;color&quot;: &quot;#ff9200ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;4627&quot;:
#                     return {&quot;color&quot;: &quot;#ff5b00ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;6040&quot;: case &quot;6969&quot;: case &quot;7125&quot;: case &quot;9655&quot;:
#                     return {&quot;color&quot;: &quot;#ffa400ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
#                 case &quot;6085&quot;: case &quot;9764&quot;:
#                     return {&quot;color&quot;: &quot;#ff2400ff&quot;, &quot;fill&quot;: true, &quot;fill_opacity&quot;: 1, &quot;radius&quot;: 3};
